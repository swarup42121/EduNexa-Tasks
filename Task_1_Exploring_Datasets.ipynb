# %%
#reading the data set from kaggle "House Price Datasets"
import pandas as pd
house_data = pd.read_csv("housing_price_dataset.csv")
house_data
# Out:
#        SquareFeet  Bedrooms  Bathrooms Neighborhood  YearBuilt          Price
# 0            2126         4          1        Rural       1969  215355.283618
# 1            2459         3          2        Rural       1980  195014.221626
# 2            1860         2          1       Suburb       1970  306891.012076
# 3            2294         2          1        Urban       1996  206786.787153
# 4            2130         5          2       Suburb       2001  272436.239065
# ...           ...       ...        ...          ...        ...            ...
# 49995        1282         5          3        Rural       1975  100080.865895
# 49996        2854         2          2       Suburb       1988  374507.656727
# 49997        2979         5          3       Suburb       1962  384110.555590
# 49998        2596         5          2        Rural       1984  380512.685957
# 49999        1572         5          3        Rural       2011  221618.583218
#
# [50000 rows x 6 columns]

# %%
#Checking the null values
null_values = house_data.isnull()
if house_data.isnull().any().any():
    print("There are null values in the DataFrame.")
else:
    print("There are no null values in the DataFrame.")
# Out:
# There are no null values in the DataFrame.

# %%
#displaying the summary statistics
summary_stats = house_data.describe()
summary_stats
# Out:
#          SquareFeet      Bedrooms     Bathrooms     YearBuilt          Price
# count  50000.000000  50000.000000  50000.000000  50000.000000   50000.000000
# mean    2006.374680      3.498700      1.995420   1985.404420  224827.325151
# std      575.513241      1.116326      0.815851     20.719377   76141.842966
# min     1000.000000      2.000000      1.000000   1950.000000  -36588.165397
# 25%     1513.000000      3.000000      1.000000   1967.000000  169955.860225
# 50%     2007.000000      3.000000      2.000000   1985.000000  225052.141166
# 75%     2506.000000      4.000000      3.000000   2003.000000  279373.630052
# max     2999.000000      5.000000      3.000000   2021.000000  492195.259972

# %%
#displaying few rows

# %%
house_data.head()
# Out:
#    SquareFeet  Bedrooms  Bathrooms Neighborhood  YearBuilt          Price
# 0        2126         4          1        Rural       1969  215355.283618
# 1        2459         3          2        Rural       1980  195014.221626
# 2        1860         2          1       Suburb       1970  306891.012076
# 3        2294         2          1        Urban       1996  206786.787153
# 4        2130         5          2       Suburb       2001  272436.239065

# %%
#displaying last few rows
house_data.tail()
# Out:
#        SquareFeet  Bedrooms  Bathrooms Neighborhood  YearBuilt          Price
# 49995        1282         5          3        Rural       1975  100080.865895
# 49996        2854         2          2       Suburb       1988  374507.656727
# 49997        2979         5          3       Suburb       1962  384110.555590
# 49998        2596         5          2        Rural       1984  380512.685957
# 49999        1572         5          3        Rural       2011  221618.583218

# %%
#displaying the number of rows and columns of datasets

# %%
#displaying the number of rows and columns of datasets
print(house_data.shape)
# Out:
# (50000, 6)

# %%
# Display unique values in a specific column
print(house_data['SquareFeet'].unique())
# Out:
# [2126 2459 1860 ... 2864 2330 2084]

# %%
# Display counts of unique values in a specific column
print(house_data['SquareFeet'].value_counts())
# Out:
# 2486    43
# 1897    41
# 2946    40
# 2573    40
# 1398    40
#         ..
# 1019    12
# 1635    12
# 2330    12
# 2087    11
# 1828    10
# Name: SquareFeet, Length: 2000, dtype: int64

# %%
# Display the correlation matrix for numeric columns
print(house_data.corr())
# Out:
#             SquareFeet  Bedrooms  Bathrooms  YearBuilt     Price
# SquareFeet    1.000000 -0.002638  -0.003275   0.000482  0.750720
# Bedrooms     -0.002638  1.000000   0.007405   0.003147  0.072624
# Bathrooms    -0.003275  0.007405   1.000000   0.003748  0.028418
# YearBuilt     0.000482  0.003147   0.003748   1.000000 -0.002288
# Price         0.750720  0.072624   0.028418  -0.002288  1.000000
# <ipython-input-21-78b27669f90b>:2: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   print(house_data.corr())

# %%
# Group by a column and calculate aggregated statistics
grouped_data = house_data.groupby('Price').agg({'Price': ['mean', 'sum']})
print(grouped_data)
# Out:
#                         Price
#                          mean            sum
# Price
# -36588.165397   -36588.165397  -36588.165397
# -28774.998022   -28774.998022  -28774.998022
# -24715.242482   -24715.242482  -24715.242482
# -24183.000515   -24183.000515  -24183.000515
# -23911.003119   -23911.003119  -23911.003119
# ...                       ...            ...
#  468493.877841  468493.877841  468493.877841
#  470989.679074  470989.679074  470989.679074
#  476671.733263  476671.733263  476671.733263
#  482577.163405  482577.163405  482577.163405
#  492195.259972  492195.259972  492195.259972
#
# [50000 rows x 2 columns]
