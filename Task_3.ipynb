# %%
# Data Cleaning and Preprocessing
import pandas as pd
sales = pd.read_csv("walmart1.csv")
sales
# Out:
#        store type  department       date  weekly_sales  is_holiday  \
# 0          1    A           1   2/5/2010      24924.50       False
# 1          1    A           1   3/5/2010      21827.90       False
# 2          1    A           1   4/2/2010      57258.43       False
# 3          1    A           1   5/7/2010      17413.94       False
# 4          1    A           1   6/4/2010      17558.09       False
# ...      ...  ...         ...        ...           ...         ...
# 10769     39    A          99  12/9/2011        895.00       False
# 10770     39    A          99   2/3/2012        350.00       False
# 10771     39    A          99   6/8/2012        450.00       False
# 10772     39    A          99  7/13/2012          0.06       False
# 10773     39    A          99  10/5/2012        915.00       False
#
#        temperature_c  fuel_price_usd_per_l  unemployment
# 0           5.727778              0.679451         8.106
# ...

# %%
# Detecting Missing Values
sales.isna()
# Out:
#        store   type  department   date  weekly_sales  is_holiday  \
# 0      False  False       False  False         False       False
# 1      False  False       False  False         False       False
# 2      False  False       False  False         False       False
# 3      False  False       False  False         False       False
# 4      False  False       False  False         False       False
# ...      ...    ...         ...    ...           ...         ...
# 10769  False  False       False  False         False       False
# 10770  False  False       False  False         False       False
# 10771  False  False       False  False         False       False
# 10772  False  False       False  False         False       False
# 10773  False  False       False  False         False       False
#
#        temperature_c  fuel_price_usd_per_l  unemployment
# 0              False                 False         False
# 1              False                 False          True
# ...

# %%
# Detecting any missing values
sales.isna().any()
# Out:
# store                   False
# type                    False
# department              False
# date                    False
# weekly_sales            False
# is_holiday              False
# temperature_c           False
# fuel_price_usd_per_l     True
# unemployment             True
# dtype: bool

# %%
# Counting missing values
sales.isna().sum()
# Out:
# store                   0
# type                    0
# department              0
# date                    0
# weekly_sales            0
# is_holiday              0
# temperature_c           0
# fuel_price_usd_per_l    2
# unemployment            3
# dtype: int64

# %%
# Plotting missing values
import matplotlib.pyplot as plt
sales.isna().sum().plot(kind="bar")
plt.show()

# %%
# Removing missing values
sales.dropna()
# Out:
#        store type  department       date  weekly_sales  is_holiday  \
# 0          1    A           1   2/5/2010      24924.50       False
# 2          1    A           1   4/2/2010      57258.43       False
# 3          1    A           1   5/7/2010      17413.94       False
# 4          1    A           1   6/4/2010      17558.09       False
# 5          1    A           1   7/2/2010      16333.14       False
# ...      ...  ...         ...        ...           ...         ...
# 10769     39    A          99  12/9/2011        895.00       False
# 10770     39    A          99   2/3/2012        350.00       False
# 10771     39    A          99   6/8/2012        450.00       False
# 10772     39    A          99  7/13/2012          0.06       False
# 10773     39    A          99  10/5/2012        915.00       False
#
#        temperature_c  fuel_price_usd_per_l  unemployment
# 0           5.727778              0.679451         8.106
# ...

# %%
# Replacing missing values
sales.fillna(0)
# Out:
#        store type  department       date  weekly_sales  is_holiday  \
# 0          1    A           1   2/5/2010      24924.50       False
# 1          1    A           1   3/5/2010      21827.90       False
# 2          1    A           1   4/2/2010      57258.43       False
# 3          1    A           1   5/7/2010      17413.94       False
# 4          1    A           1   6/4/2010      17558.09       False
# ...      ...  ...         ...        ...           ...         ...
# 10769     39    A          99  12/9/2011        895.00       False
# 10770     39    A          99   2/3/2012        350.00       False
# 10771     39    A          99   6/8/2012        450.00       False
# 10772     39    A          99  7/13/2012          0.06       False
# 10773     39    A          99  10/5/2012        915.00       False
#
#        temperature_c  fuel_price_usd_per_l  unemployment
# 0           5.727778              0.679451         8.106
# ...

# %%
# Checking the outliers
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import plotly.express as px
sales.describe()[["weekly_sales","temperature_c"]]
sales.describe()
# Out:
#               store    department   weekly_sales  temperature_c  \
# count  10774.000000  10774.000000   10774.000000   10774.000000
# mean      15.441897     45.218118   23843.950149      15.731978
# std       11.534511     29.867779   30220.387557       9.922446
# min        1.000000      1.000000   -1098.000000      -8.366667
# 25%        4.000000     20.000000    3867.115000       7.583333
# 50%       13.000000     40.000000   12049.065000      16.966667
# 75%       20.000000     72.000000   32349.850000      24.166667
# max       39.000000     99.000000  293966.050000      33.827778
#
#        fuel_price_usd_per_l  unemployment
# count          10772.000000  10771.000000
# mean               0.749750      8.082027
# std                0.059498      0.624437
# min                0.664129      3.879000
# 25%                0.708246      7.795000
# 50%                0.743381      8.099000
# 75%                0.781421      8.360000
# max                1.107674      9.765000

# %%
# Checking the outliers in the form of Histogram
sales.describe()[["weekly_sales","temperature_c"]]
fig = px.histogram(sales, x="weekly_sales")
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
# creation of a box plot
fig = px.box(sales, y="weekly_sales")
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
fig = px.scatter(x=sales["weekly_sales"], y=sales["weekly_sales"])
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
def drop_outliers_IQR(sales):

   q1=sales.quantile(0.25)

   q3=sales.quantile(0.75)

   IQR=q3-q1

   not_outliers = sales[~((df<(q1-1.5*IQR)) | (sales>(q3+1.5*IQR)))]

   outliers_dropped = outliers.dropna().reset_index()

   return outliers_dropped
sales
# Out:
#        store type  department       date  weekly_sales  is_holiday  \
# 0          1    A           1   2/5/2010      24924.50       False
# 1          1    A           1   3/5/2010      21827.90       False
# 2          1    A           1   4/2/2010      57258.43       False
# 3          1    A           1   5/7/2010      17413.94       False
# 4          1    A           1   6/4/2010      17558.09       False
# ...      ...  ...         ...        ...           ...         ...
# 10769     39    A          99  12/9/2011        895.00       False
# 10770     39    A          99   2/3/2012        350.00       False
# 10771     39    A          99   6/8/2012        450.00       False
# 10772     39    A          99  7/13/2012          0.06       False
# 10773     39    A          99  10/5/2012        915.00       False
#
#        temperature_c  fuel_price_usd_per_l  unemployment
# 0           5.727778              0.679451         8.106
# ...
